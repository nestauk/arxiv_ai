# %%
import datetime
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import numpy as np
import os
import pandas as pd
import random
import re
import requests
import time
import xml.etree.ElementTree as ET


def tokenize_alphanum(text):
    try:
        text = text.decode('utf-8')
    except AttributeError:
        pass
    words = list(filter(('').__ne__, re.split('[^a-zA-Z]',text)))
    _words = []
    for w in words:
        w = w.lower()
        w = lemmatizer.lemmatize(w)
        if w in stop_words:
            continue
        _words.append(w)
    return _words

def finished(n_papers):
    i = 0
    for filename in os.listdir("data/"):
        if not (filename.startswith("arxiv") and filename.endswith(".json")):
            continue
        i += 1
    return i*1000 >= (n_papers - 1000)

def get_file_number(n_papers):
    # Then check if any files have been generated yet                                                                                                                             
    file_numbers = []
    for filename in os.listdir("data/"):
        if not (filename.startswith("arxiv") and filename.endswith(".json")):
            continue
        file_number = int(filename.split("-")[1].split(".")[0])
        file_numbers.append(file_number)
    all_file_numbers = set(x for x in np.arange(0, n_papers, 1000))
    return random.choice(list(all_file_numbers.difference(file_numbers)))

# %%
OAI = "{http://www.openarchives.org/OAI/2.0/}"
ARXIV = "{http://arxiv.org/OAI/arXiv/}"
N_PAPERS = 1385353
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
if not os.path.exists("data"):
    os.mkdir("data")

# %%
def get_arxiv_data():
    i_req = 0
    params = dict(verb='ListRecords', metadataPrefix='arXiv')

    # Acquire a resumption token seed                                            
    r = requests.get('http://export.arxiv.org/oai2', params=params)
    xml = r.text
    root = ET.fromstring(xml)
    token = root.find(OAI+'ListRecords').find(OAI+"resumptionToken")
    seed_token = token.text.split("|")[0]
    time.sleep(25)

    all_ids = set()

    print("Using params", params)
    while True:
        output = []
        file_number = get_file_number(N_PAPERS)
        resumptionToken = seed_token+"|"+str(file_number+1)
        params = dict(verb='ListRecords', resumptionToken=resumptionToken)
        i_req = int(1 + file_number/1000)

        r = requests.get('http://export.arxiv.org/oai2', params=params)
        xml = r.text
        root = ET.fromstring(xml)
        n_ids_before = len(all_ids)
        records = root.find(OAI+'ListRecords')

        for record in records.findall(OAI+"record"):
            arxiv_id = record.find(OAI+'header').find(OAI+'identifier').text
            all_ids.add(arxiv_id)
            meta = record.find(OAI+'metadata')
            if meta is None:
                continue
            info = meta.find(ARXIV+"arXiv")
            categories = info.find(ARXIV+"categories").text
            raw_title = info.find(ARXIV+"title").text.strip()
            raw_summary = info.find(ARXIV+"abstract").text.strip()
            title = tokenize_alphanum(raw_title)
            summary = tokenize_alphanum(raw_summary)
            created = info.find(ARXIV+"created").text
            created = datetime.datetime.strptime(created, "%Y-%m-%d")
            # Fill row data                                                      
            row = dict(id=arxiv_id, categories=categories, 
                       raw_title=raw_title, raw_summary=raw_summary,
                       summary=summary, title=title, created=created)
            output.append(row)

        # Get next token                                                  
        token = root.find(OAI+'ListRecords').find(OAI+"resumptionToken")
        if token is None or token.text is None:
            break
        # params = dict(verb='ListRecords', resumptionToken=token.text)   
        # Get cursor and write to file                                    
        cursor = token.attrib['cursor']
        filename = "data/arxiv-"+str(cursor)+".json"
        d_n = len(all_ids) - n_ids_before
        print(i_req, "Writing", d_n, "to", filename, "(", token.text, ")")
        pd.DataFrame(output).to_json(filename, orient='records')
        time.sleep(25)
    return True
        
while not finished(N_PAPERS):
    try:
        get_arxiv_data()
    except Exception:
        print("Got",str(Exception))
        time.sleep(25)
        print("Restarting...")
        print()
# Out:
# Using params {'verb': 'ListRecords', 'metadataPrefix': 'arXiv'}
# 516 Writing 1000 to data/arxiv-515000.json ( 2608011|516001 )
# 34 Writing 1000 to data/arxiv-33000.json ( 2608011|34001 )
# 1173 Writing 1000 to data/arxiv-1172000.json ( 2608011|1173001 )
# 768 Writing 1000 to data/arxiv-767000.json ( 2608011|768001 )
# 87 Writing 1000 to data/arxiv-86000.json ( 2608011|87001 )
# 447 Writing 1000 to data/arxiv-446000.json ( 2608011|447001 )
# 561 Writing 1000 to data/arxiv-560000.json ( 2608011|561001 )
# 633 Writing 1000 to data/arxiv-632000.json ( 2608011|633001 )
# 831 Writing 1000 to data/arxiv-830000.json ( 2608011|831001 )
# 1354 Writing 1000 to data/arxiv-1353000.json ( 2608011|1354001 )
# 964 Writing 1000 to data/arxiv-963000.json ( 2608011|964001 )
# 77 Writing 1000 to data/arxiv-76000.json ( 2608011|77001 )
# 733 Writing 1000 to data/arxiv-732000.json ( 2608011|733001 )
# 1289 Writing 1000 to data/arxiv-1288000.json ( 2608011|1289001 )
# 1253 Writing 1000 to data/arxiv-1252000.json ( 2608011|1253001 )
# 1065 Writing 1000 to data/arxiv-1064000.json ( 2608011|1065001 )
# 1016 Writing 1000 to data/arxiv-1015000.json ( 2608011|1016001 )
# 576 Writing 1000 to data/arxiv-575000.json ( 2608011|576001 )
# 950 Writing 1000 to data/arxiv-949000.json ( 2608011|950001 )
# 877 Writing 1000 to data/arxiv-876000.json ( 2608011|877001 )
# 502 Writing 1000 to data/arxiv-501000.json ( 2608011|502001 )
# 1386 Writing 1000 to data/arxiv-1385000.json ( 2608011|1386001 )
# 92 Writing 1000 to data/arxiv-91000.json ( 2608011|92001 )
# 876 Writing 1000 to data/arxiv-875000.json ( 2608011|876001 )
# 335 Writing 1000 to data/arxiv-334000.json ( 2608011|335001 )
# 908 Writing 1000 to data/arxiv-907000.json ( 2608011|908001 )
# 981 Writing 1000 to data/arxiv-980000.json ( 2608011|981001 )
# 739 Writing 1000 to data/arxiv-738000.json ( 2608011|739001 )
# 278 Writing 1000 to data/arxiv-277000.json ( 2608011|278001 )
# 218 Writing 1000 to data/arxiv-217000.json ( 2608011|218001 )
# 723 Writing 1000 to data/arxiv-722000.json ( 2608011|723001 )
# 242 Writing 1000 to data/arxiv-241000.json ( 2608011|242001 )
# 408 Writing 1000 to data/arxiv-407000.json ( 2608011|408001 )
# 613 Writing 1000 to data/arxiv-612000.json ( 2608011|613001 )
# 1039 Writing 1000 to data/arxiv-1038000.json ( 2608011|1039001 )
# 459 Writing 1000 to data/arxiv-458000.json ( 2608011|459001 )
# 536 Writing 1000 to data/arxiv-535000.json ( 2608011|536001 )
# 1027 Writing 1000 to data/arxiv-1026000.json ( 2608011|1027001 )
# 814 Writing 1000 to data/arxiv-813000.json ( 2608011|814001 )
# 1204 Writing 1000 to data/arxiv-1203000.json ( 2608011|1204001 )
# 948 Writing 1000 to data/arxiv-947000.json ( 2608011|948001 )
# 757 Writing 1000 to data/arxiv-756000.json ( 2608011|757001 )
# 414 Writing 1000 to data/arxiv-413000.json ( 2608011|414001 )
# 1375 Writing 1000 to data/arxiv-1374000.json ( 2608011|1375001 )
# 815 Writing 1000 to data/arxiv-814000.json ( 2608011|815001 )
# 567 Writing 1000 to data/arxiv-566000.json ( 2608011|567001 )
# 1077 Writing 1000 to data/arxiv-1076000.json ( 2608011|1077001 )
# 17 Writing 1000 to data/arxiv-16000.json ( 2608011|17001 )
# 1218 Writing 1000 to data/arxiv-1217000.json ( 2608011|1218001 )
# 1030 Writing 1000 to data/arxiv-1029000.json ( 2608011|1030001 )
# 583 Writing 1000 to data/arxiv-582000.json ( 2608011|583001 )
# 682 Writing 1000 to data/arxiv-681000.json ( 2608011|682001 )
# 205 Writing 1000 to data/arxiv-204000.json ( 2608011|205001 )
# 690 Writing 1000 to data/arxiv-689000.json ( 2608011|690001 )
# 1145 Writing 1000 to data/arxiv-1144000.json ( 2608011|1145001 )
# 43 Writing 1000 to data/arxiv-42000.json ( 2608011|43001 )
# 772 Writing 1000 to data/arxiv-771000.json ( 2608011|772001 )
# 1346 Writing 1000 to data/arxiv-1345000.json ( 2608011|1346001 )
# 412 Writing 1000 to data/arxiv-411000.json ( 2608011|412001 )
# 776 Writing 1000 to data/arxiv-775000.json ( 2608011|776001 )
# 1249 Writing 1000 to data/arxiv-1248000.json ( 2608011|1249001 )
# 869 Writing 1000 to data/arxiv-868000.json ( 2608011|869001 )
# 1326 Writing 1000 to data/arxiv-1325000.json ( 2608011|1326001 )
# 751 Writing 1000 to data/arxiv-750000.json ( 2608011|751001 )
# 700 Writing 1000 to data/arxiv-699000.json ( 2608011|700001 )
# 238 Writing 1000 to data/arxiv-237000.json ( 2608011|238001 )
# 489 Writing 1000 to data/arxiv-488000.json ( 2608011|489001 )
# 36 Writing 1000 to data/arxiv-35000.json ( 2608011|36001 )
# 317 Writing 1000 to data/arxiv-316000.json ( 2608011|317001 )
# 585 Writing 1000 to data/arxiv-584000.json ( 2608011|585001 )
# 1004 Writing 1000 to data/arxiv-1003000.json ( 2608011|1004001 )
# 475 Writing 1000 to data/arxiv-474000.json ( 2608011|475001 )
# 1171 Writing 1000 to data/arxiv-1170000.json ( 2608011|1171001 )
# 1384 Writing 1000 to data/arxiv-1383000.json ( 2608011|1384001 )
# 677 Writing 1000 to data/arxiv-676000.json ( 2608011|677001 )
# 1036 Writing 1000 to data/arxiv-1035000.json ( 2608011|1036001 )
# 243 Writing 1000 to data/arxiv-242000.json ( 2608011|243001 )
# 96 Writing 1000 to data/arxiv-95000.json ( 2608011|96001 )
# 44 Writing 1000 to data/arxiv-43000.json ( 2608011|44001 )
# 746 Writing 1000 to data/arxiv-745000.json ( 2608011|746001 )
# 168 Writing 1000 to data/arxiv-167000.json ( 2608011|168001 )
# 456 Writing 1000 to data/arxiv-455000.json ( 2608011|456001 )
# 454 Writing 1000 to data/arxiv-453000.json ( 2608011|454001 )
# 47 Writing 1000 to data/arxiv-46000.json ( 2608011|47001 )
# 1193 Writing 1000 to data/arxiv-1192000.json ( 2608011|1193001 )
# 436 Writing 1000 to data/arxiv-435000.json ( 2608011|436001 )
# 164 Writing 1000 to data/arxiv-163000.json ( 2608011|164001 )
# 1244 Writing 1000 to data/arxiv-1243000.json ( 2608011|1244001 )
# 1149 Writing 1000 to data/arxiv-1148000.json ( 2608011|1149001 )
# 589 Writing 1000 to data/arxiv-588000.json ( 2608011|589001 )
# 1132 Writing 1000 to data/arxiv-1131000.json ( 2608011|1132001 )
# 1140 Writing 1000 to data/arxiv-1139000.json ( 2608011|1140001 )
# 834 Writing 1000 to data/arxiv-833000.json ( 2608011|834001 )
# 197 Writing 1000 to data/arxiv-196000.json ( 2608011|197001 )
# 1208 Writing 1000 to data/arxiv-1207000.json ( 2608011|1208001 )
# 14 Writing 1000 to data/arxiv-13000.json ( 2608011|14001 )
# 889 Writing 1000 to data/arxiv-888000.json ( 2608011|889001 )
# 393 Writing 1000 to data/arxiv-392000.json ( 2608011|393001 )
# 765 Writing 1000 to data/arxiv-764000.json ( 2608011|765001 )
# 1351 Writing 1000 to data/arxiv-1350000.json ( 2608011|1351001 )
# 737 Writing 1000 to data/arxiv-736000.json ( 2608011|737001 )
# 1256 Writing 1000 to data/arxiv-1255000.json ( 2608011|1256001 )
# 474 Writing 1000 to data/arxiv-473000.json ( 2608011|474001 )
# 1304 Writing 1000 to data/arxiv-1303000.json ( 2608011|1304001 )
# 960 Writing 1000 to data/arxiv-959000.json ( 2608011|960001 )
# 235 Writing 1000 to data/arxiv-234000.json ( 2608011|235001 )
# 505 Writing 1000 to data/arxiv-504000.json ( 2608011|505001 )
# 1045 Writing 1000 to data/arxiv-1044000.json ( 2608011|1045001 )
# 882 Writing 1000 to data/arxiv-881000.json ( 2608011|882001 )
# 99 Writing 1000 to data/arxiv-98000.json ( 2608011|99001 )
# 94 Writing 1000 to data/arxiv-93000.json ( 2608011|94001 )
# 1376 Writing 1000 to data/arxiv-1375000.json ( 2608011|1376001 )
# 1043 Writing 1000 to data/arxiv-1042000.json ( 2608011|1043001 )
# 222 Writing 1000 to data/arxiv-221000.json ( 2608011|222001 )
# 994 Writing 1000 to data/arxiv-993000.json ( 2608011|994001 )
# 792 Writing 1000 to data/arxiv-791000.json ( 2608011|792001 )
# 1227 Writing 1000 to data/arxiv-1226000.json ( 2608011|1227001 )
# 199 Writing 1000 to data/arxiv-198000.json ( 2608011|199001 )
# 420 Writing 1000 to data/arxiv-419000.json ( 2608011|420001 )
# 1136 Writing 1000 to data/arxiv-1135000.json ( 2608011|1136001 )
# 687 Writing 1000 to data/arxiv-686000.json ( 2608011|687001 )
# 42 Writing 1000 to data/arxiv-41000.json ( 2608011|42001 )
# 754 Writing 1000 to data/arxiv-753000.json ( 2608011|754001 )
# 1010 Writing 1000 to data/arxiv-1009000.json ( 2608011|1010001 )
# 1198 Writing 1000 to data/arxiv-1197000.json ( 2608011|1198001 )
# 1161 Writing 1000 to data/arxiv-1160000.json ( 2608011|1161001 )
# 1126 Writing 1000 to data/arxiv-1125000.json ( 2608011|1126001 )
# 264 Writing 1000 to data/arxiv-263000.json ( 2608011|264001 )
# 961 Writing 1000 to data/arxiv-960000.json ( 2608011|961001 )
# 1144 Writing 1000 to data/arxiv-1143000.json ( 2608011|1144001 )
# 1322 Writing 1000 to data/arxiv-1321000.json ( 2608011|1322001 )
# 916 Writing 1000 to data/arxiv-915000.json ( 2608011|916001 )
# 921 Writing 1000 to data/arxiv-920000.json ( 2608011|921001 )
# 134 Writing 1000 to data/arxiv-133000.json ( 2608011|134001 )
# 1118 Writing 1000 to data/arxiv-1117000.json ( 2608011|1118001 )
# 48 Writing 1000 to data/arxiv-47000.json ( 2608011|48001 )
# 382 Writing 1000 to data/arxiv-381000.json ( 2608011|382001 )
# 386 Writing 1000 to data/arxiv-385000.json ( 2608011|386001 )
# 577 Writing 1000 to data/arxiv-576000.json ( 2608011|577001 )
# 841 Writing 1000 to data/arxiv-840000.json ( 2608011|841001 )
# 1160 Writing 1000 to data/arxiv-1159000.json ( 2608011|1160001 )
# 185 Writing 1000 to data/arxiv-184000.json ( 2608011|185001 )
# 1294 Writing 1000 to data/arxiv-1293000.json ( 2608011|1294001 )
# 131 Writing 1000 to data/arxiv-130000.json ( 2608011|131001 )
# 209 Writing 1000 to data/arxiv-208000.json ( 2608011|209001 )
# 614 Writing 1000 to data/arxiv-613000.json ( 2608011|614001 )
# 1374 Writing 1000 to data/arxiv-1373000.json ( 2608011|1374001 )
# 1280 Writing 1000 to data/arxiv-1279000.json ( 2608011|1280001 )
# 845 Writing 1000 to data/arxiv-844000.json ( 2608011|845001 )
# 323 Writing 1000 to data/arxiv-322000.json ( 2608011|323001 )
# 478 Writing 1000 to data/arxiv-477000.json ( 2608011|478001 )
# 620 Writing 1000 to data/arxiv-619000.json ( 2608011|620001 )
# 995 Writing 1000 to data/arxiv-994000.json ( 2608011|995001 )
# 1070 Writing 1000 to data/arxiv-1069000.json ( 2608011|1070001 )
# 80 Writing 1000 to data/arxiv-79000.json ( 2608011|80001 )
# 448 Writing 1000 to data/arxiv-447000.json ( 2608011|448001 )
# 492 Writing 1000 to data/arxiv-491000.json ( 2608011|492001 )
# 104 Writing 1000 to data/arxiv-103000.json ( 2608011|104001 )
# 1101 Writing 1000 to data/arxiv-1100000.json ( 2608011|1101001 )
# 1053 Writing 1000 to data/arxiv-1052000.json ( 2608011|1053001 )
# 383 Writing 1000 to data/arxiv-382000.json ( 2608011|383001 )
# 112 Writing 1000 to data/arxiv-111000.json ( 2608011|112001 )
# 656 Writing 1000 to data/arxiv-655000.json ( 2608011|656001 )
# 469 Writing 1000 to data/arxiv-468000.json ( 2608011|469001 )
# 1152 Writing 1000 to data/arxiv-1151000.json ( 2608011|1152001 )
# 1155 Writing 1000 to data/arxiv-1154000.json ( 2608011|1155001 )
# 1313 Writing 1000 to data/arxiv-1312000.json ( 2608011|1313001 )
# 1316 Writing 1000 to data/arxiv-1315000.json ( 2608011|1316001 )
# 3 Writing 1000 to data/arxiv-2000.json ( 2608011|3001 )
# 344 Writing 1000 to data/arxiv-343000.json ( 2608011|344001 )
# 663 Writing 1000 to data/arxiv-662000.json ( 2608011|663001 )
# 1087 Writing 1000 to data/arxiv-1086000.json ( 2608011|1087001 )
# 1162 Writing 1000 to data/arxiv-1161000.json ( 2608011|1162001 )
# 1100 Writing 1000 to data/arxiv-1099000.json ( 2608011|1100001 )
# 1307 Writing 1000 to data/arxiv-1306000.json ( 2608011|1307001 )
# 410 Writing 1000 to data/arxiv-409000.json ( 2608011|410001 )
# 1008 Writing 1000 to data/arxiv-1007000.json ( 2608011|1008001 )
# 283 Writing 1000 to data/arxiv-282000.json ( 2608011|283001 )
# 1150 Writing 1000 to data/arxiv-1149000.json ( 2608011|1150001 )
# 395 Writing 1000 to data/arxiv-394000.json ( 2608011|395001 )
# 430 Writing 1000 to data/arxiv-429000.json ( 2608011|430001 )
# 1187 Writing 1000 to data/arxiv-1186000.json ( 2608011|1187001 )
# 179 Writing 1000 to data/arxiv-178000.json ( 2608011|179001 )
# 83 Writing 1000 to data/arxiv-82000.json ( 2608011|83001 )
# 68 Writing 1000 to data/arxiv-67000.json ( 2608011|68001 )
# 146 Writing 1000 to data/arxiv-145000.json ( 2608011|146001 )
# 891 Writing 1000 to data/arxiv-890000.json ( 2608011|891001 )
# 709 Writing 1000 to data/arxiv-708000.json ( 2608011|709001 )
# 761 Writing 1000 to data/arxiv-760000.json ( 2608011|761001 )
# 879 Writing 1000 to data/arxiv-878000.json ( 2608011|879001 )
# 1242 Writing 1000 to data/arxiv-1241000.json ( 2608011|1242001 )
# 573 Writing 1000 to data/arxiv-572000.json ( 2608011|573001 )
# 140 Writing 1000 to data/arxiv-139000.json ( 2608011|140001 )
# 1269 Writing 1000 to data/arxiv-1268000.json ( 2608011|1269001 )
# 610 Writing 1000 to data/arxiv-609000.json ( 2608011|610001 )
# 186 Writing 1000 to data/arxiv-185000.json ( 2608011|186001 )
# 1108 Writing 1000 to data/arxiv-1107000.json ( 2608011|1108001 )
# 946 Writing 1000 to data/arxiv-945000.json ( 2608011|946001 )
# 1172 Writing 1000 to data/arxiv-1171000.json ( 2608011|1172001 )
# 537 Writing 1000 to data/arxiv-536000.json ( 2608011|537001 )
# 490 Writing 1000 to data/arxiv-489000.json ( 2608011|490001 )
# 1314 Writing 1000 to data/arxiv-1313000.json ( 2608011|1314001 )
# 907 Writing 1000 to data/arxiv-906000.json ( 2608011|907001 )
# 147 Writing 1000 to data/arxiv-146000.json ( 2608011|147001 )
# 710 Writing 1000 to data/arxiv-709000.json ( 2608011|710001 )
# 871 Writing 1000 to data/arxiv-870000.json ( 2608011|871001 )
# 288 Writing 1000 to data/arxiv-287000.json ( 2608011|288001 )
# 523 Writing 1000 to data/arxiv-522000.json ( 2608011|523001 )
# 384 Writing 1000 to data/arxiv-383000.json ( 2608011|384001 )
# 1239 Writing 1000 to data/arxiv-1238000.json ( 2608011|1239001 )
# 646 Writing 1000 to data/arxiv-645000.json ( 2608011|646001 )
# 722 Writing 1000 to data/arxiv-721000.json ( 2608011|722001 )
# 114 Writing 1000 to data/arxiv-113000.json ( 2608011|114001 )
# 796 Writing 1000 to data/arxiv-795000.json ( 2608011|796001 )
# 1014 Writing 1000 to data/arxiv-1013000.json ( 2608011|1014001 )
# 272 Writing 1000 to data/arxiv-271000.json ( 2608011|272001 )
# 1209 Writing 1000 to data/arxiv-1208000.json ( 2608011|1209001 )
# 1033 Writing 1000 to data/arxiv-1032000.json ( 2608011|1033001 )
# 1223 Writing 1000 to data/arxiv-1222000.json ( 2608011|1223001 )
# 1082 Writing 1000 to data/arxiv-1081000.json ( 2608011|1082001 )
# 597 Writing 1000 to data/arxiv-596000.json ( 2608011|597001 )
# 1281 Writing 1000 to data/arxiv-1280000.json ( 2608011|1281001 )
# 175 Writing 1000 to data/arxiv-174000.json ( 2608011|175001 )
# 971 Writing 1000 to data/arxiv-970000.json ( 2608011|971001 )
# 1215 Writing 1000 to data/arxiv-1214000.json ( 2608011|1215001 )
# 872 Writing 1000 to data/arxiv-871000.json ( 2608011|872001 )
# 668 Writing 1000 to data/arxiv-667000.json ( 2608011|668001 )
# 300 Writing 1000 to data/arxiv-299000.json ( 2608011|300001 )
# 1348 Writing 1000 to data/arxiv-1347000.json ( 2608011|1348001 )
# 261 Writing 1000 to data/arxiv-260000.json ( 2608011|261001 )
# 808 Writing 1000 to data/arxiv-807000.json ( 2608011|808001 )
# 487 Writing 1000 to data/arxiv-486000.json ( 2608011|487001 )
# 1142 Writing 1000 to data/arxiv-1141000.json ( 2608011|1142001 )
# 1195 Writing 1000 to data/arxiv-1194000.json ( 2608011|1195001 )
# 281 Writing 1000 to data/arxiv-280000.json ( 2608011|281001 )
# 967 Writing 1000 to data/arxiv-966000.json ( 2608011|967001 )
# 54 Writing 1000 to data/arxiv-53000.json ( 2608011|54001 )
# 20 Writing 1000 to data/arxiv-19000.json ( 2608011|20001 )
# 798 Writing 1000 to data/arxiv-797000.json ( 2608011|798001 )
# 835 Writing 1000 to data/arxiv-834000.json ( 2608011|835001 )
# 575 Writing 1000 to data/arxiv-574000.json ( 2608011|575001 )
# 231 Writing 1000 to data/arxiv-230000.json ( 2608011|231001 )
# 1154 Writing 1000 to data/arxiv-1153000.json ( 2608011|1154001 )
# 226 Writing 1000 to data/arxiv-225000.json ( 2608011|226001 )
# 417 Writing 1000 to data/arxiv-416000.json ( 2608011|417001 )
# 73 Writing 1000 to data/arxiv-72000.json ( 2608011|73001 )
# 81 Writing 1000 to data/arxiv-80000.json ( 2608011|81001 )
# 391 Writing 1000 to data/arxiv-390000.json ( 2608011|391001 )
# 155 Writing 1000 to data/arxiv-154000.json ( 2608011|155001 )
# 929 Writing 1000 to data/arxiv-928000.json ( 2608011|929001 )
# 398 Writing 1000 to data/arxiv-397000.json ( 2608011|398001 )
# 275 Writing 1000 to data/arxiv-274000.json ( 2608011|275001 )
# 216 Writing 1000 to data/arxiv-215000.json ( 2608011|216001 )
# 1311 Writing 1000 to data/arxiv-1310000.json ( 2608011|1311001 )
# 1116 Writing 1000 to data/arxiv-1115000.json ( 2608011|1116001 )
# 1252 Writing 1000 to data/arxiv-1251000.json ( 2608011|1252001 )
# 124 Writing 1000 to data/arxiv-123000.json ( 2608011|124001 )
# 802 Writing 1000 to data/arxiv-801000.json ( 2608011|802001 )
# 906 Writing 1000 to data/arxiv-905000.json ( 2608011|906001 )
# 766 Writing 1000 to data/arxiv-765000.json ( 2608011|766001 )
# 252 Writing 1000 to data/arxiv-251000.json ( 2608011|252001 )
# 169 Writing 1000 to data/arxiv-168000.json ( 2608011|169001 )
# 760 Writing 1000 to data/arxiv-759000.json ( 2608011|760001 )
# 740 Writing 1000 to data/arxiv-739000.json ( 2608011|740001 )
# 673 Writing 1000 to data/arxiv-672000.json ( 2608011|673001 )
# 840 Writing 1000 to data/arxiv-839000.json ( 2608011|840001 )
# 685 Writing 1000 to data/arxiv-684000.json ( 2608011|685001 )
# 933 Writing 1000 to data/arxiv-932000.json ( 2608011|933001 )
# 259 Writing 1000 to data/arxiv-258000.json ( 2608011|259001 )
# 120 Writing 1000 to data/arxiv-119000.json ( 2608011|120001 )
# 934 Writing 1000 to data/arxiv-933000.json ( 2608011|934001 )
# 693 Writing 1000 to data/arxiv-692000.json ( 2608011|693001 )
# 552 Writing 1000 to data/arxiv-551000.json ( 2608011|552001 )
# 674 Writing 1000 to data/arxiv-673000.json ( 2608011|674001 )
# 232 Writing 1000 to data/arxiv-231000.json ( 2608011|232001 )
# 129 Writing 1000 to data/arxiv-128000.json ( 2608011|129001 )
# 503 Writing 1000 to data/arxiv-502000.json ( 2608011|503001 )
# 282 Writing 1000 to data/arxiv-281000.json ( 2608011|282001 )
# 790 Writing 1000 to data/arxiv-789000.json ( 2608011|790001 )
# 801 Writing 1000 to data/arxiv-800000.json ( 2608011|801001 )
# 935 Writing 1000 to data/arxiv-934000.json ( 2608011|935001 )
# 848 Writing 1000 to data/arxiv-847000.json ( 2608011|848001 )
# 1085 Writing 1000 to data/arxiv-1084000.json ( 2608011|1085001 )
# 494 Writing 1000 to data/arxiv-493000.json ( 2608011|494001 )
# 1350 Writing 1000 to data/arxiv-1349000.json ( 2608011|1350001 )
# 920 Writing 1000 to data/arxiv-919000.json ( 2608011|920001 )
# 914 Writing 1000 to data/arxiv-913000.json ( 2608011|914001 )
# 1183 Writing 1000 to data/arxiv-1182000.json ( 2608011|1183001 )
# 157 Writing 1000 to data/arxiv-156000.json ( 2608011|157001 )
# 201 Writing 1000 to data/arxiv-200000.json ( 2608011|201001 )
# 453 Writing 1000 to data/arxiv-452000.json ( 2608011|453001 )
# 1139 Writing 1000 to data/arxiv-1138000.json ( 2608011|1139001 )
# 65 Writing 1000 to data/arxiv-64000.json ( 2608011|65001 )
# Got <class 'Exception'>
# Restarting...

# %%
# Also create a convenience subset for articles with cs.*, stat.ML and summaries greater than 20 tokens
data = []
top_dir = "data/"
for file_name in os.listdir(top_dir):
    if not (file_name.startswith("arxiv") and file_name.endswith(".json")):
        continue
    _df = pd.read_json(top_dir+file_name,orient="records")
    _df.categories = _df.categories.apply(lambda x: x.split())
    condition = _df.categories.apply(lambda x : "stat.ML" in x) 
    condition = condition | _df.categories.apply(lambda x : any(y.startswith("cs.") for y in x))
    condition = condition & (_df.summary.apply(lambda s : len(s) > 20))
    new_df = _df.loc[condition].copy()
    data.append(new_df)
    del (_df)
df = pd.concat(data)

# %%
df.to_json("data/cs_arxiv.json", orient="records")
